# %%
# -*- coding: utf-8 -*-
# Copyright (C) 2016 Universite de Geneve, Switzerland
# E-mail contact: sebastien.leclaire@etu.unige.ch
#
# The Parity Rule
#

from numpy import *
import matplotlib.pyplot as plt
from matplotlib import cm
import copy
from imageio import imread

# Definition of functions
def readImage(string): # This function only work for monochrome BMP.
    image =  imread(string);
    image[image == 255] = 1
    image = image.astype(int)
    return image # Note that the image output is a numPy array of type "int".

# Main Program

# Program input, i.e. the name of the image "imageName" and the maximum number of iteration "maxIter"
imageName = 'image2.bmp'
maxIter   = 32

# Read the image and store it in the array "image"
image = readImage(imageName) # Note that "image" is a numPy array of type "int".
# Its element are obtained as image[i,j]
# Also, in the array "image" a white pixel correspond to an entry of 1 and a black pixel to an entry of 0.

# Get the shape of the image , i.e. the number of pixels horizontally and vertically.
# Note that the function shape return a type "tuple" (vertical_size,horizontal_size)
imageSize = shape(image);

# Print to screen the initial image.
print('Initial image:')
plt.clf()
plt.imshow(image, cmap=cm.gray)
plt.show()
plt.pause(0.1)

# Main loop
for it in range(1,maxIter+1):

    imageCopy = copy.copy(image);

    # You need to write here the core of the parity rule algorithm.
    # Altough not mandatory, you might need to use the array "imageCopy" and the tuple "imageSize".
    #
    # Code that you need to write...
    # Code that you need to write...
    for i in range(imageSize[0]):
        for j in range(imageSize[1]):
            if i==0 and j==0:
                image[i][j]=(imageCopy[i][j+1]+imageCopy[i+1][j])%2
            elif i==(imageSize)[0]-1 and j==0:
                image[i][j]=(imageCopy[i-1][j]+imageCopy[i][j+1])%2
            elif i==0 and j==imageSize[1]-1:
                image[i][j]=(imageCopy[i][j-1]+imageCopy[i+1][j])%2
            elif i==imageSize[0]-1 and j==imageSize[1]-1:
                image[i][j]=(imageCopy[i][j-1]+imageCopy[i-1][j])%2
            elif i==0:
                image[i][j]=(imageCopy[i+1][j]+imageCopy[i][j-1]+imageCopy[i][j+1])%2
            elif j==0:
                image[i][j]=(imageCopy[i-1][j]+imageCopy[i+1][j]+imageCopy[i][j+1])%2
            elif i==imageSize[0]-1:
                image[i][j]=(imageCopy[i-1][j]+imageCopy[i][j-1]+imageCopy[i][j+1])%2
            elif j==imageSize[1]-1:
                image[i][j]=(imageCopy[i-1][j]+imageCopy[i+1][j]+imageCopy[i][j-1])%2
            else:
                image[i][j]=(imageCopy[i-1][j]+imageCopy[i+1][j]+imageCopy[i][j-1]+imageCopy[i][j+1])%2
        

    # Print to screen the image after each iteration.
    print('Image after',it,'iterations:')
    plt.clf()
    plt.imshow(image, cmap=cm.gray)
    plt.show()
    plt.pause(0.1)

# Print to screen the number of white pixels in the final image
print("The number of white pixels after",it,"iterations is: ", sum(image))
# Out:
# Initial image:
# Image after 1 iterations:
# Image after 2 iterations:
# Image after 3 iterations:
# Image after 4 iterations:
# Image after 5 iterations:
# Image after 6 iterations:
# Image after 7 iterations:
# Image after 8 iterations:
# Image after 9 iterations:
# Image after 10 iterations:
# Image after 11 iterations:
# Image after 12 iterations:
# Image after 13 iterations:
# Image after 14 iterations:
# Image after 15 iterations:
# Image after 16 iterations:
# Image after 17 iterations:
# Image after 18 iterations:
# Image after 19 iterations:
# Image after 20 iterations:
# Image after 21 iterations:
# Image after 22 iterations:
# Image after 23 iterations:
# Image after 24 iterations:
# Image after 25 iterations:
# Image after 26 iterations:
# Image after 27 iterations:
# Image after 28 iterations:
# Image after 29 iterations:
# Image after 30 iterations:
# Image after 31 iterations:
# Image after 32 iterations:
# The number of white pixels after 32 iterations is:  1019
